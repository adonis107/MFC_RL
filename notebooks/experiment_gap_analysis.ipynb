# %% [markdown]
# # Experiment Figure Gap Analysis
#
# Goal: audit which requested paper figures are already covered by the benchmark notebooks and which require extended studies or future implementation.
#
# For each benchmark $e$ and result family $r$, the coverage matrix records
#
# $$
# C(e,r)\in\{\text{ready},\text{extended-ready},\text{study-needed},\text{future}\}.
# $$
#
# This notebook is a planning artifact: it does not recompute estimators, but it tells us where the saved CSV/JSON outputs already support the figures in `docs/figures.md`.
#
# Environment basics are listed in the first markdown cell of each benchmark notebook. This gap-analysis notebook has no single state or action space because it aggregates all benchmarks.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from mfc.experiments import notebook_helpers as nh

# %% [markdown]
# ## Missing Or Extra-Study Figures
#
# Goal: list result families that are not produced by the default notebook bundle or require an extended study preset.
#
# A row marked `extended-ready` means the code path exists and can be generated by running the benchmark bundle with extended studies. A row marked `future` or `study-needed` means the result still needs implementation or a richer study design.

# %%
nh.global_figure_gap_table()

# %% [markdown]
# ## Per-Benchmark Coverage
#
# Goal: inspect coverage benchmark by benchmark.
#
# Each table maps a requested figure/result to its producing command, artifact files, and notebook helper. Use this section to decide which runs must be scheduled before a complete paper-quality notebook export.

# %%
coverage = {env: nh.figure_coverage_matrix(env) for env in nh.DISCRETE_BENCHMARKS + nh.CONTINUOUS_BENCHMARKS}
coverage
